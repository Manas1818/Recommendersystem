# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib.pyplot import matplotlib as plt

# %% [markdown]
# <h1> Data Preprocessing and EDA <h1>

# %%
#importing data
df_anime = pd.read_csv("anime.csv")
df_rating = pd.read_csv("rating.csv.zip")

# %%
df_anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
df_anime.shape
# Out:
# (12294, 7)

# %%
df_anime.isna().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
df_anime.dropna(axis = 0, inplace = True)

# %%
df_rating.dropna(axis = 0, inplace = True)

# %%
df_rating.isna().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
df_anime.isna().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %%
df_anime.drop_duplicates()
df_rating.drop_duplicates()
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813736 rows x 3 columns]

# %%
df_rating.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
df_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 238.5 MB

# %%
df_rating.shape
# Out:
# (7813737, 3)

# %%
#changing datatype of anime_id to string
df_anime["anime_id"] = df_anime["anime_id"].astype(str)

# %%
df_rating["user_id"] = df_rating["user_id"].astype(str)
df_rating["anime_id"] = df_rating["anime_id"].astype(str)

# %%
df_anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12017 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12017 non-null  object
#  1   name      12017 non-null  object
#  2   genre     12017 non-null  object
#  3   type      12017 non-null  object
#  4   episodes  12017 non-null  object
#  5   rating    12017 non-null  float64
#  6   members   12017 non-null  int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 751.1+ KB

# %%
contains = [df_anime['name'].str.contains(i) for i in ["&"]]
result = df_anime[np.all(contains, axis=0)]
result
#we can see some there are a lot of names which are not cleaned
# Out:
#       anime_id                                               name  \
# 4         9969                                      Gintama&#039;
# 9        15417                           Gintama&#039;: Enchousen
# 187      28675  Kyoukai no Kanata Movie: I&#039;ll Be Here - M...
# 194      10153  Mahou Shoujo Lyrical Nanoha: The Movie 2nd A&#...
# 359       4901           Black Lagoon: Roberta&#039;s Blood Trail
# ...        ...                                                ...
# 11647    16187  Marriage Blue: &quot;Konyakusha ga Iru no ni, ...
# 11752    28169  Buta no Gotoki Sanzoku ni Torawarete Shojo wo ...
# 11971     4561                            Zoku Gosenzo San&#039;e
# 12086     2874                 Charm Point 1: Sister&#039;s Rondo
# 12127     2350  Ail Maniax: Inma Seifukugari &amp; Majogari no...
#
#                                                    genre   type episodes  \
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV       51
# 9      Action, Comedy, Historical, Parody, Samurai, S...     TV       13
# 187                 Fantasy, Slice of Life, Supernatural  Movie        1
# 194            Action, Comedy, Drama, Magic, Super Power  Movie        1
# 359                                       Action, Seinen    OVA        5
# ...                                                  ...    ...      ...
# 11647                                             Hentai    OVA        1
# 11752                                             Hentai    OVA  Unknown
# 11971                                             Hentai    OVA        4
# 12086                                             Hentai    OVA        1
# 12127                                     Demons, Hentai    OVA        3
#
#        rating  members
# 4        9.16   151266
# 9        9.11    81109
# 187      8.35    59815
# 194      8.34    13315
# 359      8.15   108099
# ...       ...      ...
# 11647    6.32     1755
# 11752    6.14     1992
# 11971    5.81      651
# 12086    5.57      868
# 12127    5.49     1793
#
# [286 rows x 7 columns]

# %%
import html

# %%
#cleaning names
df_anime['name'] = df_anime['name'].apply(html.unescape)

# %%
df_anime["type"].unique()
# Out:
# array(['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA'], dtype=object)

# %%
movies_df = df_anime[df_anime["type"] == "Movie"].sort_values(by="rating", ascending=False).head(10)
plt.pyplot.barh(movies_df["name"],movies_df["rating"])
plt.pyplot.title("Top Ten Movies")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("Movies")
# Out:
# Text(0, 0.5, 'Movies')

# %%
tv_df = df_anime[df_anime["type"] == "TV"].sort_values(by="rating", ascending=False).head(10)
plt.pyplot.barh(tv_df["name"],tv_df["rating"])
plt.pyplot.title("Top Ten TV shows")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("TV Shows")
# Out:
# Text(0, 0.5, 'TV Shows')

# %%
ova_df = df_anime[df_anime["type"] == "OVA"].sort_values(by="rating", ascending=False).head(10)
plt.pyplot.barh(ova_df["name"],ova_df["rating"])
plt.pyplot.title("Top Ten OVA shows")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("OVA Shows")
# Out:
# Text(0, 0.5, 'OVA Shows')

# %%
special_df = df_anime[df_anime["type"] == "Special"].sort_values(by="rating", ascending=False).head(10)
plt.pyplot.barh(special_df["name"],special_df["rating"])
plt.pyplot.title("Top Ten special shows")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("special Shows")
# Out:
# Text(0, 0.5, 'special Shows')

# %%
music_df = df_anime[df_anime["type"] == "Music"].sort_values(by="rating", ascending=False).head(10)
plt.pyplot.barh(music_df["name"],music_df["rating"])
plt.pyplot.title("Top Ten Music shows")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("Music Shows")
# Out:
# Text(0, 0.5, 'Music Shows')

# %%
ona_df = df_anime[df_anime["type"] == "ONA"].sort_values(by="rating", ascending=False).head(10)
plt.pyplot.barh(ona_df["name"],ona_df["rating"])
plt.pyplot.title("Top Ten ONA shows")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("ONA Shows")
# Out:
# Text(0, 0.5, 'ONA Shows')

# %%
num_ratings_df = df_rating.groupby("user_id").size().reset_index(name="num_ratings").sort_values(by="num_ratings", ascending=False)[:10]
plt.pyplot.barh(num_ratings_df["user_id"],num_ratings_df["num_ratings"])
plt.pyplot.title("User With Highest Ratings")
plt.pyplot.xlabel("Ratings")
plt.pyplot.ylabel("User IDs")
# Out:
# Text(0, 0.5, 'User IDs')

# %%
df_rating = df_rating[df_rating["rating"] >= 0]

# %%
df = df_anime.merge(df_rating, how = "left", on = ["anime_id"])
df.head()
# Out:
#   anime_id            name                                 genre   type  \
# 0    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 1    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 2    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 3    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 4    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
#
#   episodes  rating_x  members user_id  rating_y
# 0        1      9.37   200630      99       5.0
# 1        1      9.37   200630     152      10.0
# 2        1      9.37   200630     244      10.0
# 3        1      9.37   200630     271      10.0
# 4        1      9.37   200630     322      10.0

# %%
rating_counts = pd.DataFrame(df["anime_id"].value_counts())
rare_anime_df = rating_counts[rating_counts["anime_id"] <= 1000].index
common_anime_df = df[~df["anime_id"].isin(rare_anime_df)]
common_anime_df.head()
# Out:
#   anime_id            name                                 genre   type  \
# 0    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 1    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 2    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 3    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
# 4    32281  Kimi no Na wa.  Drama, Romance, School, Supernatural  Movie
#
#   episodes  rating_x  members user_id  rating_y
# 0        1      9.37   200630      99       5.0
# 1        1      9.37   200630     152      10.0
# 2        1      9.37   200630     244      10.0
# 3        1      9.37   200630     271      10.0
# 4        1      9.37   200630     322      10.0

# %%
random_user_df = common_anime_df[common_anime_df["user_id"] == str(13183)]
anime_watched = random_user_df["anime_id"].to_list()

# %%
anime_watched_df = common_anime_df[common_anime_df["anime_id"].isin(anime_watched)]

# %%
user_anime_count = anime_watched_df.groupby("user_id").size().reset_index(name="anime_watched").sort_values(by="anime_watched", ascending=False)

# %%
users_same_anime = user_anime_count[user_anime_count["anime_watched"] > 0.8*len(anime_watched)]

users_same_anime
# Out:
#       user_id  anime_watched
# 2795    13183             54
# 29189   42635             53
# 42439   57620             52
# 31858   45659             49
# 28556   41878             49
# 21224   33631             48
# 6253    17033             48
# 13471   24988             47
# 44178   59643             47
# 36838   51270             45
# 57158    8115             45
# 39856   54713             45
# 27110   40273             45
# 6313    17095             45
# 43972   59406             45
# 45466   61110             44

# %%
final_df = anime_watched_df[anime_watched_df["user_id"].isin(users_same_anime["user_id"])]
final_df
# Out:
#         anime_id             name                           genre type  \
# 26467       9253      Steins;Gate                Sci-Fi, Thriller   TV
# 27510       9253      Steins;Gate                Sci-Fi, Thriller   TV
# 28554       9253      Steins;Gate                Sci-Fi, Thriller   TV
# 28572       9253      Steins;Gate                Sci-Fi, Thriller   TV
# 30741       9253      Steins;Gate                Sci-Fi, Thriller   TV
# ...          ...              ...                             ...  ...
# 6205762    17513  Diabolik Lovers  Harem, School, Shoujo, Vampire   TV
# 6205917    17513  Diabolik Lovers  Harem, School, Shoujo, Vampire   TV
# 6205961    17513  Diabolik Lovers  Harem, School, Shoujo, Vampire   TV
# 6206066    17513  Diabolik Lovers  Harem, School, Shoujo, Vampire   TV
# 6206084    17513  Diabolik Lovers  Harem, School, Shoujo, Vampire   TV
#
#         episodes  rating_x  members user_id  rating_y
# 26467         24      9.17   673572    8115       9.0
# 27510         24      9.17   673572   13183       7.0
# 28554         24      9.17   673572   17033      10.0
# 28572         24      9.17   673572   17095       9.0
# 30741         24      9.17   673572   24988       8.0
# ...          ...       ...      ...     ...       ...
# 6205762       12      5.81   107960   45659       3.0
# 6205917       12      5.81   107960   51270       8.0
# 6205961       12      5.81   107960   54713       7.0
# 6206066       12      5.81   107960   57620       7.0
# 6206084       12      5.81   107960   59643       5.0
#
# [761 rows x 9 columns]

# %%
df_final = final_df.pivot_table(index = "user_id",
                         columns = "anime_id",
                         values = "rating_y")

# %%
corr_df = df_final.T.corr().unstack().sort_values().drop_duplicates()
corr_df = pd.DataFrame(corr_df, columns = ["corr"])
corr_df.index.names = ["user_id_1", "user_id_2"]
corr_df = corr_df.reset_index()

corr_df
# Out:
#     user_id_1 user_id_2      corr
# 0       57620     24988 -0.128512
# 1       17095     42635 -0.109050
# 2       17095     24988 -0.107052
# 3       45659     33631 -0.089890
# 4       13183     33631 -0.033636
# ..        ...       ...       ...
# 102      8115     17033  0.620468
# 103     59406     59643  0.714297
# 104     17033     59643  0.740030
# 105     13183     13183  1.000000
# 106     13183     61110       NaN
#
# [107 rows x 3 columns]

# %%
top_users= corr_df[corr_df["corr"] > 0.50]
top_users.rename(columns= {"user_id_2": "user_id"}, inplace = True)

top_users
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#     user_id_1 user_id      corr
# 92      59406   54713  0.502328
# 93      59643   40273  0.505209
# 94       8115   41878  0.509807
# 95      59406   17033  0.515680
# 96      59643   54713  0.553103
# 97      17033   51270  0.557037
# 98      51270   59406  0.565067
# 99      59406    8115  0.569910
# 100     24988   40273  0.576242
# 101      8115   59643  0.601050
# 102      8115   17033  0.620468
# 103     59406   59643  0.714297
# 104     17033   59643  0.740030
# 105     13183   13183  1.000000

# %%
top_users_rating = top_users.merge(df_rating[["user_id", "anime_id", "rating"]], how = "inner")
top_users_rating
# Out:
#       user_id_1 user_id      corr anime_id  rating
# 0         59406   54713  0.502328        1      10
# 1         59406   54713  0.502328       15       8
# 2         59406   54713  0.502328       19       9
# 3         59406   54713  0.502328       20       8
# 4         59406   54713  0.502328       24      10
# ...         ...     ...       ...      ...     ...
# 24051     13183   13183  1.000000    15085       9
# 24052     13183   13183  1.000000    15195       8
# 24053     13183   13183  1.000000    15451       8
# 24054     13183   13183  1.000000    17513       8
# 24055     13183   13183  1.000000    18041       7
#
# [24056 rows x 5 columns]

# %%
top_users_rating["weighted_rating"] = top_users_rating["corr"] * top_users_rating["rating"]

# %%
recommendation_df = top_users_rating.groupby("anime_id").agg({"weighted_rating": "mean"})
recommendation_df = recommendation_df.reset_index()
recommendation_df
# Out:
#      anime_id  weighted_rating
# 0           1         5.317042
# 1         100         2.969244
# 2        1000         5.040430
# 3       10012         5.088053
# 4       10014         3.955471
# ...       ...              ...
# 4328     9988         4.004031
# 4329     9989         5.093037
# 4330      999         2.039227
# 4331     9996         5.877933
# 4332     9999         4.341274
#
# [4333 rows x 2 columns]

# %%
anime_to_be_recommend = recommendation_df[recommendation_df["weighted_rating"] > 5.5].sort_values("weighted_rating", ascending = False)

# %%
anime_to_be_recommend.merge(df_anime[["anime_id", "name"]])
# Out:
#    anime_id  weighted_rating                                          name
# 0      1462         6.851259                                      Memories
# 1      2582         6.166133                           Soukou Kihei Votoms
# 2      3256         6.166133            Soukou Kihei Votoms: Pailsen Files
# 3      2559         6.166133                             Romeo no Aoi Sora
# 4      3508         6.166133                                  Genius Party
# ..      ...              ...                                           ...
# 63    19319         5.517517                         Gundam Build Fighters
# 64     4565         5.514321  Tengen Toppa Gurren Lagann Movie: Lagann-hen
# 65      226         5.510516                                    Elfen Lied
# 66     3784         5.510493         Evangelion: 2.0 You Can (Not) Advance
# 67      877         5.502576                                          Nana
#
# [68 rows x 3 columns]

# %%
final_anime_to_be_recommend = anime_to_be_recommend[~anime_to_be_recommend["anime_id"].isin(anime_watched)]

# %%
top_5 = df_anime[df_anime["anime_id"].isin(final_anime_to_be_recommend["anime_id"])].head(5)

top_5
# Out:
#    anime_id                           name  \
# 0     32281                 Kimi no Na wa.
# 6     11061         Hunter x Hunter (2011)
# 7       820           Ginga Eiyuu Densetsu
# 15      199  Sen to Chihiro no Kamikakushi
# 18    12355   Ookami Kodomo no Ame to Yuki
#
#                                       genre   type episodes  rating  members
# 0      Drama, Romance, School, Supernatural  Movie        1    9.37   200630
# 6   Action, Adventure, Shounen, Super Power     TV      148    9.13   425855
# 7            Drama, Military, Sci-Fi, Space    OVA      110    9.11    80679
# 15           Adventure, Drama, Supernatural  Movie        1    8.93   466254
# 18                   Fantasy, Slice of Life  Movie        1    8.84   226193
